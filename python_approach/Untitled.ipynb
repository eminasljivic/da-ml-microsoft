# %%
import os, sys
import easyocr
from pdf2image import convert_from_path
from IPython.display import display
import numpy as np
from PIL import ImageDraw

# %%
reader = easyocr.Reader(['de'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
train_dir = r'input/train'
test_dir = r'input/test'

# %%
os.listdir(train_dir)
# Out:
# ['Invoice_INV28924.pdf',
#  'Invoice_INV22366.pdf',
#  'Invoice_INV28922.pdf',
#  'Invoice_INV19929.pdf',
#  'Invoice_INV22481.pdf',
#  'Invoice_INV22331.pdf',
#  'Invoice_INV22332.pdf',
#  'Invoice_INV22236.pdf']

# %%
images = convert_from_path('input/train/'+os.listdir(train_dir)[0])
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7F88CDB47DF0>

# %%
bounds = reader.readtext(np.array(images[0]))

# %%
def draw_boxes(image, bounds):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0,*p1,*p2,*p3,*p0], fill = 'red', width = 2)
    return image

# %%
draw_boxes(images[0], bounds)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7F88CDB47DF0>

# %%
bounds
# Out:
# [([[973, 55], [1197, 55], [1197, 91], [973, 91]],
#   'Nintex UK Ltd',
#   0.8093523643418248),
#  ([[973, 87], [1451, 87], [1451, 123], [973, 123]],
#   'Ground Floor; 138 Fetter Lane',
#   0.5566640856990852),
#  ([[972, 113], [1296, 113], [1296, 161], [972, 161]],
#   'LONDON EC4A 1BT',
#   0.48960366274513123),
#  ([[975, 153], [1273, 153], [1273, 191], [975, 191]],
#   'UNITED KINGDOM',
#   0.9119196885482465),
#  ([[975, 185], [1421, 185], [1421, 227], [975, 227]],
#   'Phone: +44 (0) 20 3693 0200',
#   0.9756507134573644),
#  ([[973, 217], [1373, 217], [1373, 261], [973, 261]],
#   'Fax: +44 (0) 20 7799 4869',
#   0.5985636362311487),
#  ([[973, 255], [1239, 255], [1239, 291], [973, 291]],
#   'wwwnintex.com',
#   0.9752095750286633),
#  ([[975, 285], [1355, 285], [1355, 323], [975, 323]],
#   'VAT No. GB 139 0095 19',
#   0.8736629821326347),
#  ([[972, 374], [1358, 374], [1358, 404], [972, 404]],
#   'Please email remittance advice to:',
#   0.8867893178323939),
#  ([[107, 407], [263, 407], [263, 443], [107, 443]],
#   'Invoice To',
#   0.9063477425306652),
#  ([[300, 410], [452, 410], [452, 440], [300, 440]],
#   'ACC-031079',
#   0.956730902440753),
#  ([[974, 410], [1412, 410], [1412, 442], [974, 442]],
#   'Accountsreceivable@nintex.com',
#   0.982816714439601),
#  ([[106, 450], [473, 450], [473, 491], [106, 491]],
#   'smartpoint IT consulting GmbH',
#   0.7378503323181245),
#  ([[108, 482], [248, 482], [248, 510], [108, 510]],
#   'Strasserau 6',
#   0.9981083778675128),
#  ([[1283, 455], [1595, 455], [1595, 517], [1283, 517]],
#   'Tax Invoice',
#   0.8956197142147052),
#  ([[108, 510], [164, 510], [164, 538], [108, 538]],
#   'Linz',
#   0.9815983502894137),
#  ([[174, 510], [264, 510], [264, 540], [174, 540]],
#   'A-4020',
#   0.9999191633975055),
#  ([[110, 538], [196, 538], [196, 566], [110, 566]],
#   'Austria',
#   0.9999046619461684),
#  ([[951, 539], [1029, 539], [1029, 575], [951, 575]],
#   'Date',
#   0.9064525856249667),
#  ([[1119, 539], [1257, 539], [1257, 575], [1119, 575]],
#   'Invoice #',
#   0.9986943113612944),
#  ([[1349, 537], [1543, 537], [1543, 575], [1349, 575]],
#   'PO. Number',
#   0.9493225919799594),
#  ([[918, 600], [1060, 600], [1060, 628], [918, 628]],
#   '4-Nov-2020',
#   0.9174036237174723),
#  ([[1126, 600], [1252, 600], [1252, 630], [1126, 630]],
#   'INV28924',
#   0.9251076427958107),
#  ([[109, 671], [295, 671], [295, 707], [109, 707]],
#   'Tax Number',
#   0.9990371425214921),
#  ([[1197, 671], [1295, 671], [1295, 707], [1197, 707]],
#   'Terms',
#   0.999988004788134),
#  ([[112, 724], [280, 724], [280, 754], [112, 754]],
#   'ATU63428259',
#   0.9304229044755933),
#  ([[1204, 726], [1286, 726], [1286, 754], [1204, 754]],
#   'Net 30',
#   0.9428578807807232),
#  ([[108, 794], [238, 794], [238, 820], [108, 820]],
#   'Description',
#   0.8674110263048953),
#  ([[594, 792], [714, 792], [714, 820], [594, 820]],
#   'Start Date',
#   0.6933351608954669),
#  ([[748, 792], [856, 792], [856, 822], [748, 822]],
#   'End Date',
#   0.8281341867251597),
#  ([[898, 794], [942, 794], [942, 824], [898, 824]], 'Qty', 0.9823000719705092),
#  ([[1020, 794], [1078, 794], [1078, 820], [1020, 820]],
#   'Rate',
#   0.9990771412849426),
#  ([[1182, 792], [1284, 792], [1284, 820], [1182, 820]],
#   'Tax Rate',
#   0.9899890989464226),
#  ([[1304, 794], [1400, 794], [1400, 820], [1304, 820]],
#   'Tax Amt',
#   0.8179398596188481),
#  ([[1445, 793], [1536, 793], [1536, 821], [1445, 821]],
#   'Amount',
#   0.9999851078765465),
#  ([[108, 828], [532, 828], [532, 852], [108, 852]],
#   'Nintex Workflow-Std Edition Annual Software',
#   0.6650643213006389),
#  ([[594, 828], [714, 828], [714, 852], [594, 852]],
#   '21-Oct-2020',
#   0.860921704338519),
#  ([[746, 828], [864, 828], [864, 852], [746, 852]],
#   '20-Oct-2021',
#   0.9326537819545944),
#  ([[1080, 828], [1164, 828], [1164, 852], [1080, 852]],
#   '2,438.65',
#   0.7168918685796642),
#  ([[1232, 828], [1286, 828], [1286, 852], [1232, 852]],
#   '0.09',
#   0.922318392221691),
#  ([[1382, 828], [1428, 828], [1428, 852], [1382, 852]],
#   '0.00',
#   0.6018424242119389),
#  ([[1504, 828], [1588, 828], [1588, 852], [1504, 852]],
#   '2,438.65',
#   0.7594876557716463),
#  ([[110, 850], [206, 850], [206, 874], [110, 874]],
#   'Assurance',
#   0.9999747672078709),
#  ([[108, 894], [258, 894], [258, 918], [108, 918]],
#   'Nintex Late Fee',
#   0.88940831719759),
#  ([[594, 894], [714, 894], [714, 918], [594, 918]],
#   '21-Oct-2020',
#   0.860921704338519),
#  ([[746, 892], [864, 892], [864, 918], [746, 918]],
#   '20-Oct-2021',
#   0.7653059115671419),
#  ([[1098, 894], [1164, 894], [1164, 918], [1098, 918]],
#   '487.73',
#   0.9880167959837007),
#  ([[1232, 894], [1286, 894], [1286, 918], [1232, 918]],
#   '0.09',
#   0.922318392221691),
#  ([[1382, 894], [1428, 894], [1428, 918], [1382, 918]],
#   '0.00',
#   0.6018424242119389),
#  ([[1522, 892], [1590, 892], [1590, 918], [1522, 918]],
#   '487.73',
#   0.9983594664019869),
#  ([[110, 1602], [752, 1602], [752, 1634], [110, 1634]],
#   'End User: IKT LINZ INFRASTRUKTUR Gmbh (KUK Linz)',
#   0.5678933140312793),
#  ([[110, 1628], [322, 1628], [322, 1656], [110, 1656]],
#   'End User Account:',
#   0.9153368919074322),
#  ([[1207, 1621], [1275, 1621], [1275, 1654], [1207, 1654]],
#   'Total',
#   0.999988004788134),
#  ([[1488, 1624], [1594, 1624], [1594, 1654], [1488, 1654]],
#   '2,926.38',
#   0.7993951412732337),
#  ([[1208, 1652], [1374, 1652], [1374, 1682], [1208, 1682]],
#   'Balance Due',
#   0.7387286024629057),
#  ([[1476, 1652], [1594, 1652], [1594, 1684], [1476, 1684]],
#   'e,926.38',
#   0.3332054105859467),
#  ([[110, 1702], [276, 1702], [276, 1726], [110, 1726]],
#   'This is a reverse',
#   0.7019992416208817),
#  ([[275, 1700], [1346, 1700], [1346, 1731], [275, 1731]],
#   'charge supply_VAT is due in the country of the recipient pursuant to Article 196 of the EC Directive 2006/112',
#   0.6743313332647427),
#  ([[108, 1722], [668, 1722], [668, 1748], [108, 1748]],
#   'PLEASE NOTE OUR BANK DETAILS HAVE CHANGED',
#   0.7162841407457083),
#  ([[1273, 1729], [1490, 1729], [1490, 1762], [1273, 1762]],
#   'Currency in Euro',
#   0.7402777351408892),
#  ([[124, 1746], [242, 1746], [242, 1770], [124, 1770]],
#   'Credit Card',
#   0.9864040480928904),
#  ([[254, 1746], [310, 1746], [310, 1770], [254, 1770]],
#   'VISA',
#   0.5646253334671596),
#  ([[316, 1745], [1134, 1745], [1134, 1775], [316, 1775]],
#   'Mastercard and American Express are accepted by Nintex. Please request a credit',
#   0.8448255489061345),
#  ([[108, 1768], [658, 1768], [658, 1794], [108, 1794]],
#   'card authorization form to make payment by credit card.',
#   0.678551071039133),
#  ([[124, 1790], [414, 1790], [414, 1816], [124, 1816]],
#   'EFT Transfer: Account Name',
#   0.9954793305375531),
#  ([[424, 1790], [794, 1790], [794, 1818], [424, 1818]],
#   'Nintex UK Ltd; Bank: HSBC Bank plc',
#   0.8122461644169209),
#  ([[110, 1812], [196, 1812], [196, 1838], [110, 1838]],
#   'Address',
#   0.9999026388166959),
#  ([[208, 1810], [894, 1810], [894, 1840], [208, 1840]],
#   'City of London Branch, 60 Queen Victoria Street, London, EC4N 4TR',
#   0.6847967756278295),
#  ([[110, 1834], [270, 1834], [270, 1862], [110, 1862]],
#   'EUR Payments:',
#   0.9982695570678817),
#  ([[110, 1855], [748, 1855], [748, 1884], [110, 1884]],
#   'Bank Routing Number (SWIFT): HBUKGBAB Sort Code: 401276',
#   0.9468321296851191),
#  ([[765, 1855], [1044, 1855], [1044, 1883], [765, 1883]],
#   'Account Number:76005900',
#   0.8173306299531817),
#  ([[108, 1878], [474, 1878], [474, 1904], [108, 1904]],
#   'IBAN: GB12HBUK40127676005900',
#   0.6180797444960372),
#  ([[110, 1901], [270, 1901], [270, 1929], [110, 1929]],
#   'USD Payments:',
#   0.9941857956161299),
#  ([[110, 1921], [748, 1921], [748, 1950], [110, 1950]],
#   'Bank Routing Number (SWIFT): HBUKGB4B Sort Code: 401276',
#   0.8325125633999849),
#  ([[774, 1924], [1054, 1924], [1054, 1948], [774, 1948]],
#   'Account Number: 76005868',
#   0.668918408738566),
#  ([[108, 1946], [464, 1946], [464, 1970], [108, 1970]],
#   'IBAN:GBO3HBUK40127676005868',
#   0.7848437964679252),
#  ([[110, 1967], [270, 1967], [270, 1995], [110, 1995]],
#   'GBP Payments:',
#   0.9997018789284796),
#  ([[108, 1989], [554, 1989], [554, 2018], [108, 2018]],
#   'Bank Routing Number (SWIFT): HBUKGBAB',
#   0.9384796611704449),
#  ([[574, 1990], [766, 1990], [766, 2016], [574, 2016]],
#   'Sort Code: 401160',
#   0.9988579413641832),
#  ([[108, 2012], [390, 2012], [390, 2038], [108, 2038]],
#   'Account Number: 80108588',
#   0.9955414346846214),
#  ([[408, 2012], [770, 2012], [770, 2038], [408, 2038]],
#   'IBAN: GBI8HBUK40116080108588',
#   0.6887134664910408),
#  ([[124, 2033], [610, 2033], [610, 2063], [124, 2063]],
#   'Cheque: Made payable to Nintex UK Ltd, Ground',
#   0.8802339653228627),
#  ([[672, 2034], [834, 2034], [834, 2060], [672, 2060]],
#   '138 Fetter Lane',
#   0.6491440777522317),
#  ([[108, 2055], [524, 2055], [524, 2082], [108, 2082]],
#   'LONDON EC4A 1BT, UNITED KINGDOM',
#   0.6826089020754885),
#  ([[108, 2080], [802, 2080], [802, 2106], [108, 2106]],
#   'Please email remittance advices to: AccountsReceivable@Nintex.com',
#   0.7111841703961997),
#  ([[110, 2122], [1310, 2122], [1310, 2153], [110, 2153]],
#   'Unless otherwise expressly agreed between Customer and Nintex; by paying the Subscription; Support; or License fees in',
#   0.6533157161392719),
#  ([[108, 2144], [1250, 2144], [1250, 2174], [108, 2174]],
#   'this Invoice; Customer is accepting all of the terms and conditions of the applicable Nintex agreement(s) available at',
#   0.5498425546453721),
#  ([[610.9580569325292, 2031.1867537178289],
#    [673.9132150793114, 2039.283635636235],
#    [670.0419430674708, 2063.813246282171],
#    [607.0867849206886, 2055.716364363765]],
#   'Floor;',
#   0.6508955008504549)]
